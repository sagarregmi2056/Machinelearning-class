# %%
import pandas as pd 

import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

dataframe= pd.read_csv("/home/sagaregmi/projects/personal-projects/machine-learning/data-cleaning-series/Airbnb_Open_Data.csv")

dataframe.head()

dataframe.columns

dataframe.info()


dataframe["license"]
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  str
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  str
#  4   host name                       102193 non-null  str
#  5   neighbourhood group             102570 non-null  str
#  6   neighbourhood                   102583 non-null  str
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  str
#  10  country code                    102468 non-null  str
#  11  instant_bookable                102494 non-null  object
# ...

# %% [markdown]
# step1: deleting reduandent columns.

# %%
dataframe.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='str')

# %%
columns_to_keep=[ 'NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review']
columns_to_drop=['review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license','id']


len(columns_to_keep)

len(columns_to_drop)
# Out:
# 6

# %%
len(columns_to_keep)
# Out:
# 19

# %% [markdown]
# method1: filtering data

# %%
df=dataframe[columns_to_keep]

# %%
df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
df.shape
# Out:
# (102599, 19)

# %% [markdown]
# method2: Dropping columns

# %%
dataframe
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %% [markdown]
# steps2: renaming the columns.

# %%
df.columns


new_columns=[]
for value in df.columns:
    new_columns.append(value.upper())

    
new_columns
# Out:
# ['NAME',
#  'HOST ID',
#  'HOST_IDENTITY_VERIFIED',
#  'HOST NAME',
#  'NEIGHBOURHOOD GROUP',
#  'NEIGHBOURHOOD',
#  'LAT',
#  'LONG',
#  'COUNTRY',
#  'COUNTRY CODE',
#  'INSTANT_BOOKABLE',
#  'CANCELLATION_POLICY',
#  'ROOM TYPE',
#  'CONSTRUCTION YEAR',
#  'PRICE',
#  'SERVICE FEE',
#  'MINIMUM NIGHTS',
#  'NUMBER OF REVIEWS',
#  'LAST REVIEW']

# %%
new_dataframes_tomodify= df.copy()

new_dataframes_tomodify.columns= new_columns

new_dataframes_tomodify
# Out:
#                                                     NAME      HOST ID  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        HOST_IDENTITY_VERIFIED    HOST NAME NEIGHBOURHOOD GROUP  \
# ...

# %% [markdown]
# step3:now time to see the duplicated rows in the newdataframestomodify

# %%
new_dataframes_tomodify.duplicated().value_counts()
# her the true values count is total number of rows duplicates
# Out:
# False    102058
# True        541
# Name: count, dtype: int64

# %%
# this will drop the duplicate columns
new_dataframes_tomodify.drop_duplicates(inplace=True)

# we will get null true values
new_dataframes_tomodify.duplicated().value_counts()
new_dataframes_tomodify.describe()
# Out:
#             HOST ID            LAT           LONG  CONSTRUCTION YEAR  \
# count  1.020580e+05  102050.000000  102050.000000      101844.000000
# mean   4.926738e+10      40.728097     -73.949652        2012.488090
# std    2.853742e+10       0.055852       0.049502           5.765838
# min    1.236005e+08      40.499790     -74.249840        2003.000000
# 25%    2.459924e+10      40.688730     -73.982580        2007.000000
# 50%    4.912865e+10      40.722290     -73.954440        2012.000000
# 75%    7.400619e+10      40.762760     -73.932350        2017.000000
# max    9.876313e+10      40.916970     -73.705220        2022.000000
#
#        MINIMUM NIGHTS  NUMBER OF REVIEWS
# count   101658.000000      101875.000000
# mean         8.126640          27.517948
# std         30.616698          49.571744
# min      -1223.000000           0.000000
# 25%          2.000000           1.000000
# 50%          3.000000           7.000000
# 75%          5.000000          31.000000
# ...

# %% [markdown]
# step3:clean the NaN value

# %%
# new_dataframes_tomodify.dropna(columns=["LAST REVIEW"],inplace=True)

new_dataframes_tomodify.isna().sum()
# Out:
# NAME                      250
# HOST ID                     0
# HOST_IDENTITY_VERIFIED    289
# HOST NAME                 404
# NEIGHBOURHOOD GROUP        29
# NEIGHBOURHOOD              16
# LAT                         8
# LONG                        8
# COUNTRY                   532
# COUNTRY CODE              131
# INSTANT_BOOKABLE          105
# CANCELLATION_POLICY        76
# ROOM TYPE                   0
# CONSTRUCTION YEAR         214
# PRICE                     247
# SERVICE FEE               273
# MINIMUM NIGHTS            400
# NUMBER OF REVIEWS         183
# dtype: int64

# %%
new_dataframes_tomodify.isna().sum()
# Out:
# NAME                      250
# HOST ID                     0
# HOST_IDENTITY_VERIFIED    289
# HOST NAME                 404
# NEIGHBOURHOOD GROUP        29
# NEIGHBOURHOOD              16
# LAT                         8
# LONG                        8
# COUNTRY                   532
# COUNTRY CODE              131
# INSTANT_BOOKABLE          105
# CANCELLATION_POLICY        76
# ROOM TYPE                   0
# CONSTRUCTION YEAR         214
# PRICE                     247
# SERVICE FEE               273
# MINIMUM NIGHTS            400
# NUMBER OF REVIEWS         183
# dtype: int64

# %%
new_dataframes_tomodify.dropna(inplace=True)

new_dataframes_tomodify


new_dataframes_tomodify.isna().sum()
# Out:
# NAME                      0
# HOST ID                   0
# HOST_IDENTITY_VERIFIED    0
# HOST NAME                 0
# NEIGHBOURHOOD GROUP       0
# NEIGHBOURHOOD             0
# LAT                       0
# LONG                      0
# COUNTRY                   0
# COUNTRY CODE              0
# INSTANT_BOOKABLE          0
# CANCELLATION_POLICY       0
# ROOM TYPE                 0
# CONSTRUCTION YEAR         0
# PRICE                     0
# SERVICE FEE               0
# MINIMUM NIGHTS            0
# NUMBER OF REVIEWS         0
# dtype: int64

# %% [markdown]
# steps4:cleaning the individual columns

# %%
# new_dataframes_tomodify["HOST_IDENTITY_VERIFIED"].str.upper()

new_dataframes_tomodify["HOST_IDENTITY_VERIFIED"]=new_dataframes_tomodify["HOST_IDENTITY_VERIFIED"].str.upper()

new_dataframes_tomodify["HOST_IDENTITY_VERIFIED"]



# new_dataframes_tomodify["INSTANT_BOOKABLE"].apply(lambda x:1 if x==True else 0)

new_dataframes_tomodify["INSTANT_BOOKABLE"]=new_dataframes_tomodify["INSTANT_BOOKABLE"].apply(lambda x:1 if x==True else 0)


new_dataframes_tomodify.head()

# from the data we are seeing the index and data are not in order we need to make the index order by using 

new_dataframes_tomodify.reset_index(inplace=True)


new_dataframes_tomodify["INSTANT_BOOKABLE"][0]
# Out:
#    level_0  index                                              NAME  \
# 0        0      0                Clean & quiet apt home by the park
# 1        1      1                             Skylit Midtown Castle
# 2        2      4  Entire Apt: Spacious Studio/Loft by central park
# 3        3      5         Large Cozy 1 BR Apartment In Midtown East
# 4        4      7                                   BlissArtsSpace!
#
#        HOST ID HOST_IDENTITY_VERIFIED HOST NAME NEIGHBOURHOOD GROUP  \
# 0  80014485718            UNCONFIRMED  Madaline            Brooklyn
# 1  52335172823               VERIFIED     Jenna           Manhattan
# 2  92037596077               VERIFIED    Lyndon           Manhattan
# 3  45498551794               VERIFIED  Michelle           Manhattan
# 4  90821839709            UNCONFIRMED      Emma            Brooklyn
#
#         NEIGHBOURHOOD       LAT      LONG        COUNTRY COUNTRY CODE  \
# 0          Kensington  40.64749 -73.97237  United States           US
# ...

# %%
new_dataframes_tomodify["INSTANT_BOOKABLE"][2]
type(new_dataframes_tomodify["INSTANT_BOOKABLE"][2])
# Out:
# numpy.int64

# %%
new_dataframes_tomodify

# still the dollor sign is in the price we need to remove dollor sign and transform it to integer

new_dataframes_tomodify["PRICE"]


# this output str which means the price is in string value
type(new_dataframes_tomodify["PRICE"][0])  



new_dataframes_tomodify["PRICE"].head()

# new_dataframes_tomodify["PRICE"].str.replace("$","")




type(new_dataframes_tomodify["PRICE"][0])  
# still the data type of the price is str we need to make it integer


# new_dataframes_tomodify["PRICE"].astype(int)

new_dataframes_tomodify["PRICE"]=new_dataframes_tomodify["PRICE"].astype(int)

new_dataframes_tomodify["PRICE"][1]


new_dataframes_tomodify.to_csv("cleaned_airbnb_data.csv")

# %%
pd.read_csv("/home/sagaregmi/projects/personal-projects/machine-learning/data-cleaning-series/cleaned_airbnb_data.csv")

new_dataframes_tomodify.to_csv("cleanedfinaldata",index=False)

# %%
finaldata= pd.read_csv("cleanedfinaldata")
finaldata.head()

finaldata.drop(columns=["index"],inplace=True)
finaldata.head()

finaldata["SERVICE FEE"].str.replace("$","")


finaldata["SERVICE FEE"]=finaldata["SERVICE FEE"].str.replace("$","")


finaldata["SERVICE FEE"]=finaldata["SERVICE FEE"].str.replace(" ","")

# now empty space and data is cleaned we need to convert it into string

finaldata["SERVICE FEE"]=finaldata["SERVICE FEE"].astype(int)

type(finaldata["SERVICE FEE"][20])
# Out:
# numpy.int64

# %%
# now final output to the finalizedata.csv


finaldata.to_csv("finalizecleaneddata.csv")

finaldata.head()
# Out:
#    level_0                                              NAME      HOST ID  \
# 0        0                Clean & quiet apt home by the park  80014485718
# 1        1                             Skylit Midtown Castle  52335172823
# 2        2  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3        3         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4        4                                   BlissArtsSpace!  90821839709
#
#   HOST_IDENTITY_VERIFIED HOST NAME NEIGHBOURHOOD GROUP       NEIGHBOURHOOD  \
# 0            UNCONFIRMED  Madaline            Brooklyn          Kensington
# 1               VERIFIED     Jenna           Manhattan             Midtown
# 2               VERIFIED    Lyndon           Manhattan         East Harlem
# 3               VERIFIED  Michelle           Manhattan         Murray Hill
# 4            UNCONFIRMED      Emma            Brooklyn  Bedford-Stuyvesant
#
# ...

# %% [markdown]
# Now starts visualization

# %%
visualizationdata=pd.read_csv("finalizecleaneddata.csv")
sns.countplot(x='CONSTRUCTION YEAR',hue='PRICE', data=visualizationdata)

plt.title("Country spending by price")
plt.ylabel("price range")
plt.xlabel("construction by year")
plt.show()
# Out:
# /home/sagaregmi/projects/personal-projects/machine-learning/venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
