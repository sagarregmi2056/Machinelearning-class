# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df =sns.load_dataset('titanic')

# print(df.head(10))

# print(df.info(verbose=True))

# print(df.shape)

# print(df.isnull().sum())

# print(df.describe())

# we are adding mean as mean data for dataframe here.
df['age']=  df['age'].fillna(df['age'].mean())


# print(df.isnull().sum())

# print(df.tail(10))

print(sns.countplot(x='survived', data=df))

# sns.title("Survival Count")
plt.show()


sns.countplot(x='sex',hue='survived', data=df)

plt.title("Survival Rate by Sex")
plt.show()


# sns.barplot(x='pclass',hue='survived', data=df)

# plt.title("Survival Rate by Pclass")



# histogram
# plt.hist(df['age'], bins=20)
# plt.xlabel("Age")
# plt.ylabel("Frequency")
# plt.title("Age Distribution")
# plt.show()




# df.isnull().sum()

# recurring data lai count garxa ani lagyarw paila kai ma mean change directly on original column
# df['embark_town'].fillna(df['embark_town'].mode()[0], inplace=True)

# the above is same as the below code
df['embark_town'] = df['embark_town'].fillna(df['embark_town'].mode()[0])


df.isnull().sum()


# show unique values in embark_town column
df['embark_town'].unique()


# how many people embarked from each town
df['embark_town'].value_counts()


# correlation 

dummy_df = df[['survived', 'fare', 'age']].corr()



sns.heatmap(dummy_df, annot=True)
# Out:
# Axes(0.125,0.11;0.775x0.77)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 76
#      71 df['embark_town'].value_counts()
#      74 # correlation
# ---> 76 dummy_df = df[['survived', 'sex', 'age']].corr()
#      80 sns.heatmap(dummy_df, annot=True)
#
# File ~/projects/personal-projects/machine-learning/venv/lib/python3.12/site-packages/pandas/core/frame.py:13117, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13115 cols = data.columns
#   13116 idx = cols.copy()
# > 13117 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13119 if method == "pearson":
#   13120     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/projects/personal-projects/machine-learning/venv/lib/python3.12/site-packages/pandas/core/frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2079 if dtype is not None:
# ...
